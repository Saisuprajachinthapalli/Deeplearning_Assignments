# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from pandas import read_csv
from keras.models import Sequential, Model
from keras.layers import Dense, LSTM, Input
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# load the dataset
dataframe = pd.read_csv('/content/sample_data/airline-passengers.csv', usecols=[1], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')

# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# reshape into X=t and Y=t+1
# look_back: number of previous steps
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))

# Show shape of train & test
print('Shape of train And test')
print(trainX.shape)
print(trainY.shape)
print(testX.shape)
print(testY.shape)

print("-------------------------------------------------------------------------")

# create and fit the LSTM network

model = Sequential()
model.add(LSTM(4, input_shape=(look_back, 1)))
model.add(Dense(1))

print("input_shape=(number of steps = look_back, number of features = 1)")

model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)

trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# calculate root mean squared error
trainPredict[:] = np.nan_to_num(trainPredict)
testPredict[:] = np.nan_to_num(testPredict)
trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:,0]))

print("-------------------------------------------------------------------------")
# Compute testScore (complete O,O)

print("testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:,0]))")

print("-------------------------------------------------------------------------")

# Print trainScore & testScore

print('Train Score: %.2f RMSE' % (trainScore))
print('Test Score: %.2f RMSE' % (testScore))


# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)

# Show the plot

plt.show()

print("-----------------------------------------------------------------")

 # 2) change look_back values to 1, 3 and 5, respectively. Compare the results using mean square error.

print("Changing the LOOK_BACK value to 1")

# reshape into X=t and Y=t+1
# look_back: number of previous steps
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))

# create and fit the LSTM network

model = Sequential()
model.add(LSTM(4, input_shape=(look_back, 1)))
model.add(Dense(1))



model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)

trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# calculate root mean squared error
trainPredict[:] = np.nan_to_num(trainPredict)
testPredict[:] = np.nan_to_num(testPredict)
trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:,0]))


print("-------------------------------------------------------------------------")

# Print trainScore & testScore

print('Train Score: %.2f RMSE' % (trainScore))
print('Test Score: %.2f RMSE' % (testScore))


# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)

# Show the plot

plt.show()

print("--------------------------------------------------------------------------------------------")

print("Changing the LOOK_BACK value to 5")

# reshape into X=t and Y=t+1
# look_back: number of previous steps
look_back = 5
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))

# create and fit the LSTM network

model = Sequential()
model.add(LSTM(4, input_shape=(look_back, 1)))
model.add(Dense(1))


model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)

trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# calculate root mean squared error
trainPredict[:] = np.nan_to_num(trainPredict)
testPredict[:] = np.nan_to_num(testPredict)
trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:,0]))

print("-------------------------------------------------------------------------")

# Print trainScore & testScore

print('Train Score: %.2f RMSE' % (trainScore))
print('Test Score: %.2f RMSE' % (testScore))


# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)

# Show the plot

plt.show()

print("---------------------------------------------------------------")


# 3) add another LSTM layer and compare the results using mean square error.

print('adding another LSTM layer and comparing the results using mean square error.')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense, LSTM

# Define create_dataset function
def create_dataset(dataset, look_back):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i + look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# Load and normalize the dataset
dataframe = pd.read_csv('/content/sample_data/airline-passengers.csv', usecols=[1])
dataset = dataframe.values.astype('float32')
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# Split the dataset into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[:train_size], dataset[train_size:]

# Reshape the data into X and Y sets for training and testing
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# Reshape the input data to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))

# Create the LSTM model with an additional LSTM layer
model = Sequential()
model.add(LSTM(4, return_sequences=True, input_shape=(look_back, 1)))
model.add(LSTM(4))  # Second LSTM layer
model.add(Dense(1))  # Dense layer

# Compile the model
model.compile(loss='mean_squared_error', optimizer='adam')

# Train the model
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)

# Make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# Invert the predictions and actual values
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# Calculate root mean squared error
trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:, 0]))
testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:, 0]))

# Print the train and test scores
print('Train Score: %.2f RMSE' % trainScore)
print('Test Score: %.2f RMSE' % testScore)

# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)

# Show the plot

plt.show()
# Out:
# Shape of train And test
# (92, 3, 1)
# (92,)
# (44, 3, 1)
# (44,)
# -------------------------------------------------------------------------
# input_shape=(number of steps = look_back, number of features = 1)
# Epoch 1/100
# 92/92 - 2s - loss: 0.0434 - 2s/epoch - 27ms/step
# Epoch 2/100
# 92/92 - 0s - loss: 0.0181 - 219ms/epoch - 2ms/step
# Epoch 3/100
# 92/92 - 0s - loss: 0.0146 - 210ms/epoch - 2ms/step
# Epoch 4/100
# 92/92 - 0s - loss: 0.0131 - 197ms/epoch - 2ms/step
# Epoch 5/100
# 92/92 - 0s - loss: 0.0115 - 200ms/epoch - 2ms/step
# Epoch 6/100
# 92/92 - 0s - loss: 0.0101 - 219ms/epoch - 2ms/step
# Epoch 7/100
# 92/92 - 0s - loss: 0.0089 - 211ms/epoch - 2ms/step
# Epoch 8/100
# 92/92 - 0s - loss: 0.0077 - 201ms/epoch - 2ms/step
# Epoch 9/100
# 92/92 - 0s - loss: 0.0067 - 194ms/epoch - 2ms/step
# Epoch 10/100
# 92/92 - 0s - loss: 0.0059 - 197ms/epoch - 2ms/step
# Epoch 11/100
# 92/92 - 0s - loss: 0.0054 - 212ms/epoch - 2ms/step
# Epoch 12/100
# 92/92 - 0s - loss: 0.0048 - 202ms/epoch - 2ms/step
# Epoch 13/100
# 92/92 - 0s - loss: 0.0046 - 198ms/epoch - 2ms/step
# Epoch 14/100
# 92/92 - 0s - loss: 0.0044 - 205ms/epoch - 2ms/step
# Epoch 15/100
# 92/92 - 0s - loss: 0.0044 - 196ms/epoch - 2ms/step
# Epoch 16/100
# 92/92 - 0s - loss: 0.0042 - 214ms/epoch - 2ms/step
# Epoch 17/100
# 92/92 - 0s - loss: 0.0041 - 192ms/epoch - 2ms/step
# Epoch 18/100
# 92/92 - 0s - loss: 0.0041 - 199ms/epoch - 2ms/step
# Epoch 19/100
# 92/92 - 0s - loss: 0.0042 - 198ms/epoch - 2ms/step
# Epoch 20/100
# 92/92 - 0s - loss: 0.0041 - 198ms/epoch - 2ms/step
# Epoch 21/100
# 92/92 - 0s - loss: 0.0040 - 217ms/epoch - 2ms/step
# Epoch 22/100
# 92/92 - 0s - loss: 0.0040 - 196ms/epoch - 2ms/step
# Epoch 23/100
# 92/92 - 0s - loss: 0.0040 - 193ms/epoch - 2ms/step
# Epoch 24/100
# 92/92 - 0s - loss: 0.0040 - 198ms/epoch - 2ms/step
# Epoch 25/100
# 92/92 - 0s - loss: 0.0041 - 210ms/epoch - 2ms/step
# Epoch 26/100
# 92/92 - 0s - loss: 0.0040 - 235ms/epoch - 3ms/step
# Epoch 27/100
# 92/92 - 0s - loss: 0.0041 - 206ms/epoch - 2ms/step
# Epoch 28/100
# 92/92 - 0s - loss: 0.0040 - 205ms/epoch - 2ms/step
# Epoch 29/100
# 92/92 - 0s - loss: 0.
# 90/90 - 0s - loss: 0.0149 - 373ms/epoch - 4ms/step
# Epoch 4/100
# 90/90 - 0s - loss: 0.0130 - 343ms/epoch - 4ms/step
# Epoch 5/100
# 90/90 - 0s - loss: 0.0111 - 321ms/epoch - 4ms/step
# Epoch 6/100
# 90/90 - 0s - loss: 0.0098 - 309ms/epoch - 3ms/step
# Epoch 7/100
# 90/90 - 0s - loss: 0.0084 - 398ms/epoch - 4ms/step
# Epoch 8/100
# 90/90 - 0s - loss: 0.0074 - 385ms/epoch - 4ms/step
# Epoch 9/100
# 90/90 - 0s - loss: 0.0065 - 298ms/epoch - 3ms/step
# Epoch 10/100
# 90/90 - 0s - loss: 0.0058 - 240ms/epoch - 3ms/step
# Epoch 11/100
# 90/90 - 0s - loss: 0.0055 - 255ms/epoch - 3ms/step
# Epoch 12/100
# 90/90 - 0s - loss: 0.0052 - 247ms/epoch - 3ms/step
# Epoch 13/100
# 90/90 - 0s - loss: 0.0051 - 239ms/epoch - 3ms/step
# Epoch 14/100
# 90/90 - 0s - loss: 0.0050 - 247ms/epoch - 3ms/step
# Epoch 15/100
# 90/90 - 0s - loss: 0.0049 - 238ms/epoch - 3ms/step
# Epoch 16/100
# 90/90 - 0s - loss: 0.0049 - 260ms/epoch - 3ms/step
# Epoch 17/100
# 90/90 - 0s - loss: 0.0048 - 255ms/epoch - 3ms/step
# Epoch 18/100
# 90/90 - 0s - loss: 0.0048 - 246ms/epoch - 3ms/step
# Epoch 19/100
# 90/90 - 0s - loss: 0.0048 - 266ms/epoch - 3ms/step
# Epoch 20/100
# 90/90 - 0s - loss: 0.0047 - 250ms/epoch - 3ms/step
# Epoch 21/100
# 90/90 - 0s - loss: 0.0045 - 245ms/epoch - 3ms/step
# Epoch 22/100
# 90/90 - 0s - loss: 0.0046 - 257ms/epoch - 3ms/step
# Epoch 23/100
# 90/90 - 0s - loss: 0.0045 - 265ms/epoch - 3ms/step
# Epoch 24/100
# 90/90 - 0s - loss: 0.0045 - 237ms/epoch - 3ms/step
# Epoch 25/100
# 90/90 - 0s - loss: 0.0045 - 249ms/epoch - 3ms/step
# Epoch 26/100
# 90/90 - 0s - loss: 0.0045 - 265ms/epoch - 3ms/step
# Epoch 27/100
# 90/90 - 0s - loss: 0.0043 - 270ms/epoch - 3ms/step
# Epoch 28/100
# 90/90 - 0s - loss: 0.0043 - 243ms/epoch - 3ms/step
# Epoch 29/100
# 90/90 - 0s - loss: 0.0043 - 240ms/epoch - 3ms/step
# Epoch 30/100
# 90/90 - 0s - loss: 0.0041 - 247ms/epoch - 3ms/step
# Epoch 31/100
# 90/90 - 0s - loss: 0.0042 - 264ms/epoch - 3ms/step
# Epoch 32/100
# 90/90 - 0s - loss: 0.0041 - 239ms/epoch - 3ms/step
# Epoch 33/100
# 90/90 - 0s - loss: 0.0042 - 242ms/epoch - 3ms/step
# Epoch 34/100
# 90/90 - 0s - loss: 0.0041 - 246ms/epoch - 3ms/step
# Epoch 35/100
# 90/90 - 0s - loss: 0.0041 - 277ms/epoch - 3ms/step
# Epoch 36/100
# 90/90 - 0s - loss: 0.0039 - 232ms/epoch - 3ms/step
# Epoch 37/100
# 90/90 - 0s - loss: 0.0039 - 234ms/epoch - 3ms/step
# Epoch 38/100
# 90/90 - 0s - loss: 0.0041 - 247ms/epoch - 3ms/step
# Epoch 39/100
# 90/90 - 0s - loss: 0.0039 - 260ms/epoch - 3ms/step
# Epoch 40/100
# 90/90 - 0s - loss: 0.0039 - 250ms/epoch - 3ms/step
# Epoch 41/100
# 90/90 - 0s - loss: 0.0037 - 238ms/epoch - 3ms/step
# Epoch 42/100
# 90/90 - 0s - loss: 0.0038 - 252ms/epoch - 3ms/step
# Epoch 43/100
# 90/90 - 0s - loss: 0.0038 - 251ms/epoch - 3ms/step
# Epoch 44/100
# 90/90 - 0s - loss: 0.0037 - 241ms/epoch - 3ms/step
# Epoch 45/100
# 90/90 - 0s - loss: 0.0039 - 230ms/epoch - 3ms/step
# Epoch 46/100
# 90/90 - 0s - loss: 0.0036 - 236ms/epoch - 3ms/step
# Epoch 47/100
# 90/90 - 0s - loss: 0.0035 - 233ms/epoch - 3ms/step
# Epoch 48/100
# 90/90 - 0s - loss: 0.0034 - 255ms/epoch - 3ms/step
# Epoch 49/100
# 90/90 - 0s - loss: 0.0035 - 345ms/epoch - 4ms/step
# Epoch 50/100
# 90/90 - 0s - loss: 0.0035 - 340ms/epoch - 4ms/step
# Epoch 51/100
# 90/90 - 0s - loss: 0.0033 - 363ms/epoch - 4ms/step
# Epoch 52/100
# 90/90 - 0s - loss: 0.0035 - 353ms/epoch - 4ms/step
# Epoch 53/100
# 90/90 - 0s - loss: 0.0034 - 369ms/epoch - 4ms/step
# Epoch 54/100
# 90/90 - 0s - loss: 0.0034 - 382ms/epoch - 4ms/step
# Epoch 55/100
# 90/90 - 0s - loss: 0.0030 - 371ms/epoch - 4ms/step
# Epoch 56/100
# 90/90 - 0s - loss: 0.0033 - 234ms/epoch - 3ms/step
# Epoch 57/100
# 90/90 - 0s - loss: 0.0032 - 242ms/epoch - 3ms/step
# Epoch 58/100
# 90/90 - 0s - loss: 0.0031 - 232ms/epoch - 3ms/step
# Epoch 59/100
# 90/90 - 0s - loss: 0.0031 - 259ms/epoch - 3ms/step
# Epoch 60/100
# 90/90 - 0s - loss: 0.0030 - 252ms/epoch - 3ms/step
# Epoch 61/100
# 90/90 - 0s - loss: 0.0030 - 264ms/epoch - 3ms/step
# Epoch 62/100
# 90/90 - 0s - loss: 0.0029 - 247ms/epoch - 3ms/step
# Epoch 63/100
# 90/90 - 0s - loss: 0.0030 - 264ms/epoch - 3ms/step
# Epoch 64/100
# 90/90 - 0s - loss: 0.0029 - 273ms/epoch - 3ms/step
# Epoch 65/100
# 90/90 - 0s - loss: 0.0028 - 267ms/epoch - 3ms/step
# Epoch 66/100
# 90/90 - 0s - loss: 0.0027 - 250ms/epoch - 3ms/step
# Epoch 67/100
# 90/90 - 0s - loss: 0.0028 - 259ms/epoch - 3ms/step
# Epoch 68/100
# 90/90 - 0s - loss: 0.0027 - 250ms/epoch - 3ms/step
# Epoch 69/100
# 90/90 - 0s - loss: 0.0027 - 280ms/epoch - 3ms/step
# Epoch 70/100
# 90/90 - 0s - loss: 0.0027 - 270ms/epoch - 3ms/step
# Epoch 71/100
# 90/90 - 0s - loss: 0.0025 - 254ms/epoch - 3ms/step
# Epoch 72/100
# 90/90 - 0s - loss: 0.0025 - 251ms/epoch - 3ms/step
# Epoch 73/100
# 90/90 - 0s - loss: 0.0026 - 253ms/epoch - 3ms/step
# Epoch 74/100
# 90/90 - 0s - loss: 0.0025 - 230ms/epoch - 3ms/step
# Epoch 75/100
# 90/90 - 0s - loss: 0.0024 - 247ms/epoch - 3ms/step
# Epoch 76/100
# 90/90 - 0s - loss: 0.0024 - 248ms/epoch - 3ms/step
# Epoch 77/100
# 90/90 - 0s - loss: 0.0023 - 261ms/epoch - 3ms/step
# Epoch 78/100
# 90/90 - 0s - loss: 0.0024 - 243ms/epoch - 3ms/step
# Epoch 79/100
# 90/90 - 0s - loss: 0.0024 - 255ms/epoch - 3ms/step
# Epoch 80/100
# 90/90 - 0s - loss: 0.0025 - 233ms/epoch - 3ms/step
# Epoch 81/100
# 90/90 - 0s - loss: 0.0023 - 249ms/epoch - 3ms/step
# Epoch 82/100
# 90/90 - 0s - loss: 0.0022 - 251ms/epoch - 3ms/step
# Epoch 83/100
# 90/90 - 0s - loss: 0.0021 - 257ms/epoch - 3ms/step
# Epoch 84/100
# 90/90 - 0s - loss: 0.0022 - 247ms/epoch - 3ms/step
# Epoch 85/100
# 90/90 - 0s - loss: 0.0021 - 259ms/epoch - 3ms/step
# Epoch 86/100
# 90/90 - 0s - loss: 0.0021 - 233ms/epoch - 3ms/step
# Epoch 87/100
# 90/90 - 0s - loss: 0.0021 - 237ms/epoch - 3ms/step
# Epoch 88/100
# 90/90 - 0s - loss: 0.0023 - 232ms/epoch - 3ms/step
# Epoch 89/100
# 90/90 - 0s - loss: 0.0023 - 241ms/epoch - 3ms/step
# Epoch 90/100
# 90/90 - 0s - loss: 0.0022 - 242ms/epoch - 3ms/step
# Epoch 91/100
# 90/90 - 0s - loss: 0.0021 - 253ms/epoch - 3ms/step
# Epoch 92/100
# 90/90 - 0s - loss: 0.0022 - 233ms/epoch - 3ms/step
# Epoch 93/100
# 90/90 - 0s - loss: 0.0020 - 255ms/epoch - 3ms/step
# Epoch 94/100
# 90/90 - 0s - loss: 0.0021 - 236ms/epoch - 3ms/step
# Epoch 95/100
# 90/90 - 0s - loss: 0.0020 - 346ms/epoch - 4ms/step
# Epoch 96/100
# 90/90 - 0s - loss: 0.0022 - 360ms/epoch - 4ms/step
# Epoch 97/100
# 90/90 - 0s - loss: 0.0020 - 361ms/epoch - 4ms/step
# Epoch 98/100
# 90/90 - 0s - loss: 0.0023 - 372ms/epoch - 4ms/step
# Epoch 99/100
# 90/90 - 0s - loss: 0.0020 - 391ms/epoch - 4ms/step
# Epoch 100/100
# 90/90 - 0s - loss: 0.0020 - 378ms/epoch - 4ms/step
# 3/3 [==============================] - 1s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# -------------------------------------------------------------------------
# Train Score: 22.82 RMSE
# Test Score: 49.48 RMSE
# ---------------------------------------------------------------
# Epoch 1/100
# 92/92 - 4s - loss: 0.0386 - 4s/epoch - 39ms/step
# Epoch 2/100
# 92/92 - 0s - loss: 0.0161 - 327ms/epoch - 4ms/step
# Epoch 3/100
# 92/92 - 0s - loss: 0.0141 - 343ms/epoch - 4ms/step
# Epoch 4/100
# 92/92 - 0s - loss: 0.0127 - 325ms/epoch - 4ms/step
# Epoch 5/100
# 92/92 - 0s - loss: 0.0106 - 336ms/epoch - 4ms/step
# Epoch 6/100
# 92/92 - 0s - loss: 0.0088 - 332ms/epoch - 4ms/step
# Epoch 7/100
# 92/92 - 0s - loss: 0.0068 - 315ms/epoch - 3ms/step
# Epoch 8/100
# 92/92 - 0s - loss: 0.0058 - 321ms/epoch - 3ms/step
# Epoch 9/100
# 92/92 - 0s - loss: 0.0052 - 332ms/epoch - 4ms/step
# Epoch 10/100
# 92/92 - 0s - loss: 0.0054 - 320ms/epoch - 3ms/step
# Epoch 11/100
# 92/92 - 0s - loss: 0.0052 - 312ms/epoch - 3ms/step
# Epoch 12/100
# 92/92 - 0s - loss: 0.0050 - 330ms/epoch - 4ms/step
# Epoch 13/100
# 92/92 - 0s - loss: 0.